# %%
import yfinance
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # grabbing the stock series from list of tickers

# %%
stock_list = ['AAPL', 'MSFT', 'AMZN', 'GOOGL', 'META', 'TSLA', 'NVDA', 'NFLX', 'ADBE', 'PYPL']

# %%
price_data = {}
for ticker in stock_list:
    price_data[ticker] = yfinance.download(ticker, start = '2024-01-01', end = '2024-04-17')
price_data
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# {'AAPL':                   Open        High         Low       Close   Adj Close  \
#  Date
#  2024-01-02  187.149994  188.440002  183.889999  185.639999  185.403412
#  2024-01-03  184.220001  185.880005  183.429993  184.250000  184.015198
# ...

# %%
attribute = 'Close'

# %%
close__price_dfclose__price_df = pd.DataFrame({ticker: price_data[ticker]['Close'] for ticker in stock_list})
close__price_df.head()
# Out:
#                   AAPL        MSFT        AMZN       GOOGL        META  \
# Date
# 2024-01-02  185.639999  370.869995  149.929993  138.169998  346.290009
# 2024-01-03  184.250000  370.600006  148.470001  138.919998  344.470001
# 2024-01-04  181.910004  367.940002  144.570007  136.389999  347.119995
# 2024-01-05  181.179993  367.750000  145.240005  135.729996  351.950012
# 2024-01-08  185.559998  374.690002  149.100006  138.839996  358.660004
#
#                   TSLA        NVDA        NFLX        ADBE       PYPL
# Date
# 2024-01-02  248.419998  481.679993  468.500000  580.070007  61.459999
# 2024-01-03  238.449997  475.690002  470.260010  571.789978  58.630001
# 2024-01-04  237.929993  479.980011  474.670013  567.049988  58.450001
# 2024-01-05  237.490005  490.970001  474.059998  564.599976  60.119999
# 2024-01-08  240.449997  522.530029  485.029999  580.549988  61.740002

# %%
close__price_df.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
d
